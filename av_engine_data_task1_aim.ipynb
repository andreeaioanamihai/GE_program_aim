# %% [markdown]
# # Task 1 : Data Engineering

# %% [markdown]
# ### **Libraries**

# %%
import pandas as pd

# %%
#Load data

df1 = pd.read_csv(r"C:\Users\andre\Downloads\ge\av_engine_aic_psql.csv")

# %%
df1.head()
# Out:
#        dataset     esn  unit  flight_cycle         datetime operator  \
# 0  train_FD001  999001     1             1  1/11/2018 17:10      AIC
# 1  train_FD001  999001     1             2   1/12/2018 1:07      AIC
# 2  train_FD001  999001     1             3   1/12/2018 2:06      AIC
# 3  train_FD001  999001     1             4   1/12/2018 7:42      AIC
# 4  train_FD001  999001     1             5   1/12/2018 8:42      AIC
#
#   depart_icao destination_icao  hpc_eff_mod  hpc_flow_mod  ...     phi  \
# 0        VTBS             VICG      -0.0005        0.0002  ...  521.93
# 1        VICG             VTBS       0.0016       -0.0003  ...  521.72
# 2        VICG             VTBS      -0.0017        0.0001  ...  521.97
# 3        VTBS             VIDP      -0.0012       -0.0002  ...  522.04
# 4        VTBS             VIDP       0.0027        0.0001  ...  522.25
#
#        nrf      nrc     bpr  farb  htbleed  nf_dmd  pcnfr_dmd    w31      w32
# ...

# %%
df2 = pd.read_csv(r"C:\Users\andre\Downloads\ge\av_engine_axm_psql.csv")

# %%
df2.head()
# Out:
#       dataset     esn  unit  flight_cycle          datetime operator  \
# 0  test_FD001  999126    26             1  12/31/2017 18:33      AXM
# 1  test_FD001  999126    26             2  12/31/2017 19:59      AXM
# 2  test_FD001  999126    26             3  12/31/2017 21:44      AXM
# 3  test_FD001  999126    26             4     1/1/2018 0:50      AXM
# 4  test_FD001  999126    26             5     1/1/2018 4:25      AXM
#
#   depart_icao destination_icao  hpc_eff_mod  hpc_flow_mod  ...     phi  \
# 0        VTBD             VTUV      -0.0027        0.0006  ...  522.55
# 1        VTUV             VTBD      -0.0029        0.0002  ...  521.85
# 2        VTBD             VMMC       0.0008        0.0001  ...  522.34
# 3        VMMC             VTBD      -0.0026        0.0005  ...  522.03
# 4        VTBD             VTSP       0.0020        0.0005  ...  522.04
#
#        nrf      nrc     bpr  farb  htbleed  nf_dmd  pcnfr_dmd    w31      w32
# ...

# %%
df3 = pd.read_csv(r"C:\Users\andre\Downloads\ge\av_engine_fron_psql.csv")

# %%
df3.head()
# Out:
#        dataset     esn  unit  flight_cycle        datetime operator  \
# 0  train_FD001  999050    50             1   1/6/2018 6:01     FRON
# 1  train_FD001  999050    50             2   1/6/2018 7:41     FRON
# 2  train_FD001  999050    50             3   1/6/2018 8:41     FRON
# 3  train_FD001  999050    50             4  1/6/2018 10:14     FRON
# 4  train_FD001  999050    50             5  1/6/2018 11:12     FRON
#
#   depart_icao destination_icao  hpc_eff_mod  hpc_flow_mod  ...     phi  \
# 0        KMCO             KMSY      -0.0029       -0.0002  ...  521.68
# 1        KMSY             KSAT      -0.0002       -0.0005  ...  522.12
# 2        KMSY             KSAT      -0.0010       -0.0005  ...  521.96
# 3        KSAT             KSAN      -0.0061       -0.0002  ...  522.31
# 4        KSAT             KSAN      -0.0002        0.0001  ...  522.05
#
#        nrf      nrc     bpr  farb  htbleed  nf_dmd  pcnfr_dmd    w31      w32
# ...

# %%
df4 = pd.read_csv(r"C:\Users\andre\Downloads\ge\av_engine_pgt_psql.csv")

# %%
df4.head()
# Out:
#        dataset     esn  unit  flight_cycle        datetime operator  \
# 0  train_FD001  999050    50             1   1/6/2018 6:01     FRON
# 1  train_FD001  999050    50             2   1/6/2018 7:41     FRON
# 2  train_FD001  999050    50             3   1/6/2018 8:41     FRON
# 3  train_FD001  999050    50             4  1/6/2018 10:14     FRON
# 4  train_FD001  999050    50             5  1/6/2018 11:12     FRON
#
#   depart_icao destination_icao  hpc_eff_mod  hpc_flow_mod  ...     phi  \
# 0        KMCO             KMSY      -0.0029       -0.0002  ...  521.68
# 1        KMSY             KSAT      -0.0002       -0.0005  ...  522.12
# 2        KMSY             KSAT      -0.0010       -0.0005  ...  521.96
# 3        KSAT             KSAN      -0.0061       -0.0002  ...  522.31
# 4        KSAT             KSAN      -0.0002        0.0001  ...  522.05
#
#        nrf      nrc     bpr  farb  htbleed  nf_dmd  pcnfr_dmd    w31      w32
# ...

# %% [markdown]
# ### **Merging all Engine Datasets**

# %%
df = pd.concat([df1, df2, df3, df4], axis=0)

# %%
df.head()
# Out:
#        dataset     esn  unit  flight_cycle         datetime operator  \
# 0  train_FD001  999001     1             1  1/11/2018 17:10      AIC
# 1  train_FD001  999001     1             2   1/12/2018 1:07      AIC
# 2  train_FD001  999001     1             3   1/12/2018 2:06      AIC
# 3  train_FD001  999001     1             4   1/12/2018 7:42      AIC
# 4  train_FD001  999001     1             5   1/12/2018 8:42      AIC
#
#   depart_icao destination_icao  hpc_eff_mod  hpc_flow_mod  ...     phi  \
# 0        VTBS             VICG      -0.0005        0.0002  ...  521.93
# 1        VICG             VTBS       0.0016       -0.0003  ...  521.72
# 2        VICG             VTBS      -0.0017        0.0001  ...  521.97
# 3        VTBS             VIDP      -0.0012       -0.0002  ...  522.04
# 4        VTBS             VIDP       0.0027        0.0001  ...  522.25
#
#        nrf      nrc     bpr  farb  htbleed  nf_dmd  pcnfr_dmd    w31      w32
# ...

# %%
df.reset_index(drop = True, inplace = True)

# %%
df.head()
# Out:
#        dataset     esn  unit  flight_cycle         datetime operator  \
# 0  train_FD001  999001     1             1  1/11/2018 17:10      AIC
# 1  train_FD001  999001     1             2   1/12/2018 1:07      AIC
# 2  train_FD001  999001     1             3   1/12/2018 2:06      AIC
# 3  train_FD001  999001     1             4   1/12/2018 7:42      AIC
# 4  train_FD001  999001     1             5   1/12/2018 8:42      AIC
#
#   depart_icao destination_icao  hpc_eff_mod  hpc_flow_mod  ...     phi  \
# 0        VTBS             VICG      -0.0005        0.0002  ...  521.93
# 1        VICG             VTBS       0.0016       -0.0003  ...  521.72
# 2        VICG             VTBS      -0.0017        0.0001  ...  521.97
# 3        VTBS             VIDP      -0.0012       -0.0002  ...  522.04
# 4        VTBS             VIDP       0.0027        0.0001  ...  522.25
#
#        nrf      nrc     bpr  farb  htbleed  nf_dmd  pcnfr_dmd    w31      w32
# ...

# %%
df.to_csv("av_engine_data.csv", index = False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41588 entries, 0 to 41587
# Data columns (total 32 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   dataset           41588 non-null  object
#  1   esn               41588 non-null  int64
#  2   unit              41588 non-null  int64
#  3   flight_cycle      41588 non-null  int64
#  4   datetime          41588 non-null  object
#  5   operator          41588 non-null  object
#  6   depart_icao       40696 non-null  object
#  7   destination_icao  40423 non-null  object
#  8   hpc_eff_mod       41588 non-null  float64
#  9   hpc_flow_mod      41588 non-null  float64
#  10  tra               41588 non-null  int64
#  11  t2                41588 non-null  float64
#  12  t24               41588 non-null  float64
#  13  t30               41588 non-null  float64
#  14  t50               41588 non-null  float64
#  15  p2                41588 non-null  float64
# ...

# %%
df['t24'] = df['t24'] + 459.67

# %%
df
# Out:
#            dataset     esn  unit  flight_cycle         datetime operator  \
# 0      train_FD001  999001     1             1  1/11/2018 17:10      AIC
# 1      train_FD001  999001     1             2   1/12/2018 1:07      AIC
# 2      train_FD001  999001     1             3   1/12/2018 2:06      AIC
# 3      train_FD001  999001     1             4   1/12/2018 7:42      AIC
# 4      train_FD001  999001     1             5   1/12/2018 8:42      AIC
# ...            ...     ...   ...           ...              ...      ...
# 41583  train_FD001  999086    86           271    2/8/2018 8:24     FRON
# 41584  train_FD001  999086    86           272   2/8/2018 13:16     FRON
# 41585  train_FD001  999086    86           273   2/8/2018 14:16     FRON
# 41586  train_FD001  999086    86           274   2/8/2018 18:21     FRON
# 41587  train_FD001  999086    86           275    2/9/2018 9:05     FRON
#
#       depart_icao destination_icao  hpc_eff_mod  hpc_flow_mod  ...     phi  \
# ...

# %%
df['t24'].value_counts()
# Out:
# 1102.16    362
# 1102.17    356
# 1102.34    352
# 1102.12    346
# 1102.23    336
#           ...
# 644.17       1
# 644.02       1
# 644.04       1
# 644.16       1
# 644.13       1
# Name: t24, Length: 580, dtype: int64

# %%
df.to_csv(r"C:\Users\andre\Downloads\ge\av_engine_data_task1_aim.csv", index = False)
